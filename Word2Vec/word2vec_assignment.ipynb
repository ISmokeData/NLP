# %% [markdown]
# ## **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import gensim
import os
import string
import re
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from gensim.utils import simple_preprocess
from sklearn.decomposition import PCA
import plotly.express as px
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# removing punctuation mark
def remove_punc1(text):
    return text.translate(str.maketrans('', '', exclude))

# %%
# remove \n in text
def replace_newlines(text):
    return re.sub(r'\n+', ' ', text).strip()

# %%
# remove stopwords
stop_words = set(stopwords.words('english'))  # Convert to set for faster lookup

def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in stop_words])

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %% [markdown]
# # **Steps**
# - **Importing Data**
# - **Tokenize Data (Sentence)**
# - **Remove Punctuation
# - **Remove newlines**
# - **Remove StopWords**
# - **Convert into Simple Preprocess**

# %%
exclude = string.punctuation
story = []
f = open(os.path.join('data', 'Friends_Transcript.txt'),encoding='utf-8', errors='ignore')
corpus = f.read()
raw_sent = sent_tokenize(corpus)
for sent in raw_sent:
    removed_punc_newline = replace_newlines(remove_punc1(sent))
    processed_sent = simple_preprocess(remove_stopwords(removed_punc_newline.lower()))
    if processed_sent:  # Ensure the sentence isn't empty
                story.append(processed_sent)

# %%
print(f"Corpus lenght :  {len(corpus)}")
print(f"Number of sentences : {len(raw_sent)}")
print(f"story length : {len(story)}")
# Out:
# Corpus lenght :  4899189
# Number of sentences : 117572
# story length : 115646

# %%
story
# Out:
# [['one',
#   'monica',
#   'gets',
#   'new',
#   'roomate',
#   'pilotthe',
#   'uncut',
#   'version',
#   'written',
#   'marta',
#   'kauffman',
#   'david',
#   'crane',
#   'scene',
#   'central',
#   'perk',
#   'chandler',
#   'joey',
#   'phoebe',
#   'monica'],
#  ['monica', 'theres', 'nothing', 'tell'],
#  ['hes', 'guy', 'work'],
#  ['joey', 'cmon', 'youre', 'going', 'guy'],
#  ['theres', 'gotta', 'something', 'wrong'],
#  ['chandler', 'right', 'joey', 'nice'],
#  ['hump'],
#  ['hump', 'hairpiece'],
#  ['phoebe', 'wait', 'eat', 'chalk'],
#  ['stare', 'bemused'],
#  ['phoebe', 'cause', 'dont', 'want', 'go', 'went', 'carl', 'oh'],
#  ['monica', 'okay', 'everybody', 'relax'],
#  ['even', 'date'],
#  ['two', 'people', 'going', 'dinner', 'sex'],
#  ['chandler', 'sounds', 'like', 'date'],
#  ['time',
#   'lapse',
#   'chandler',
#   'alright',
#   'im',
#   'back',
#   'high',
#   'school',
#   'im',
#   'standing',
#   'middle',
#   'cafeteria',
#   'realize',
#   'totally',
#   'naked'],
#  ['oh', 'yeah'],
#  ['dream'],
#  ['chandler', 'look', 'realize', 'theres', 'phone'],
#  ['joey', 'instead'],
#  ['chandler', 'thats', 'right'],
#  ['joey', 'never', 'dream'],
#  ['phoebe'],
#  ['chandler', 'sudden', 'phone', 'starts', 'ring'],
#  ['dont', 'know', 'everybody', 'starts', 'looking'],
#  ['monica', 'werent', 'looking'],
#  ['chandler',
#   'finally',
#   'figure',
#   'id',
#   'better',
#   'answer',
#   'turns',
#   'mother',
#   'veryvery',
#   'weird',
#   'never',
#   'calls'],
#  ['time', 'lapse', 'ross', 'entered'],
#  ['ross', 'mortified', 'hi'],
#  ['joey', 'guy', 'says', 'hello', 'wanna', 'kill'],
#  ['monica', 'okay', 'sweetie'],
#  ['ross',
#   'feel',
#   'like',
#   'someone',
#   'reached',
#   'throat',
#   'grabbed',
#   'small',
#   'intestine',
#   'pulled',
#   'mouth',
#   'tied',
#   'around',
#   'neck',
#   'chandler',
#   'cookie'],
#  ['monica', 'explaining', 'others', 'carol', 'moved', 'stuff', 'today'],
#  ['joey', 'ohh'],
#  ['monica', 'ross', 'let', 'get', 'coffee'],
#  ['ross', 'thanks'],
#  ['phoebe', 'ooh'],
#  ['oh'],
#  ['starts', 'pluck', 'air', 'front', 'ross'],
#  ['ross', 'dont'],
#  ['stop', 'cleansing', 'aura'],
#  ['leave', 'aura', 'alone', 'okay'],
#  ['phoebe', 'fine'],
#  ['murky'],
#  ['ross', 'ill', 'fine', 'alright'],
#  ['really', 'everyone'],
#  ['hope', 'shell', 'happy'],
#  ['monica', 'dont'],
#  ['ross', 'dont', 'hell', 'left'],
#  ['joey', 'never', 'knew', 'lesbian', 'ross'],
#  ['okay'],
#  ['everyone', 'keep', 'fixating'],
#  ['didnt', 'know', 'know'],
#  ['chandler', 'sometimes', 'wish', 'lesbian', 'stare'],
#  ['say', 'loud'],
#  ['ross',
#   'told',
#   'mom',
#   'dad',
#   'last',
#   'night',
#   'seemed',
#   'take',
#   'pretty',
#   'well'],
#  ['monica',
#   'oh',
#   'really',
#   'hysterical',
#   'phone',
#   'call',
#   'got',
#   'woman',
#   'sobbing',
#   'ill',
#   'never',
#   'grandchildren',
#   'ill',
#   'never',
#   'grandchildren'],
#  ['wrong', 'number'],
#  ['ross', 'sorry'],
#  ['joey', 'alright', 'ross', 'look'],
#  ['youre', 'feeling', 'lot', 'pain', 'right'],
#  ['youre', 'angry'],
#  ['youre', 'hurting'],
#  ['tell', 'answer'],
#  ['ross', 'gestures', 'consent'],
#  ['joey', 'strip', 'joint'],
#  ['cmon', 'youre', 'single'],
#  ['hormones'],
#  ['ross', 'dont', 'want', 'single', 'okay'],
#  ['wanna', 'married'],
#  ['rachel', 'enters', 'wet', 'wedding', 'dress', 'starts', 'search', 'room'],
#  ['chandler', 'want', 'million', 'dollars'],
#  ['extends', 'hand', 'hopefully'],
#  ['monica', 'rachel'],
#  ['rachel', 'oh', 'god', 'monica', 'hi'],
#  ['thank', 'god'],
#  ['went', 'building', 'werent', 'guy', 'big', 'hammer', 'said', 'might'],
#  ['waitress', 'get', 'coffee'],
#  ['monica', 'pointing', 'rachel', 'decaff'],
#  ['okay', 'everybody', 'rachel', 'another', 'lincoln', 'high', 'survivor'],
#  ['rachel',
#   'everybody',
#   'chandler',
#   'phoebe',
#   'joey',
#   'remember',
#   'brother',
#   'ross'],
#  ['rachel', 'hi', 'sure'],
#  ['ross', 'hi'],
#  ['go', 'hug', 'rosss', 'umbrella', 'opens'],
#  ['sits', 'back', 'defeated'],
#  ['moment',
#   'silence',
#   'follows',
#   'rachel',
#   'sits',
#   'others',
#   'expect',
#   'explain'],
#  ['monica', 'wanna', 'tell', 'us', 'waiting', 'four', 'wet', 'bridesmaids'],
#  ['rachel', 'oh', 'god', 'well', 'started', 'half', 'hour', 'wedding'],
#  ['room', 'keeping', 'presents', 'looking', 'gravy', 'boat'],
#  ['really', 'gorgeous', 'lamauge', 'gravy', 'boat'],
#  ['sudden',
#   'waitress',
#   'brought',
#   'coffeesweet',
#   'lo',
#   'realized',
#   'turned',
#   'gravy',
#   'boat',
#   'barry'],
#  ['got',
#   'really',
#   'freaked',
#   'thats',
#   'hit',
#   'much',
#   'barry',
#   'looks',
#   'like',
#   'mr'],
#  ['potato', 'head'],
#  ['yknow', 'mean', 'always', 'knew', 'looked', 'familiar'],
#  ['anyway', 'get', 'started', 'wondering'],
#  ['monica',
#   'anyway',
#   'didnt',
#   'know',
#   'go',
#   'know',
#   'kinda',
#   'drifted',
#   'apart',
#   'youre',
#   'person',
#   'knew',
#   'lived',
#   'city'],
#  ['monica', 'wasnt', 'invited', 'wedding'],
#  ['rachel',
#   'ooh',
#   'kinda',
#   'hoping',
#   'wouldnt',
#   'issue',
#   'scene',
#   'monicas',
#   'apartment',
#   'everyone',
#   'watching',
#   'spanish',
#   'soap',
#   'tv',
#   'trying',
#   'figure',
#   'going'],
#  ['monica',
#   'im',
#   'guessing',
#   'bought',
#   'big',
#   'pipe',
#   'organ',
#   'shes',
#   'really',
#   'happy'],
#  ['chandler', 'imitating', 'characters', 'tuna', 'egg', 'salad'],
#  ['decide'],
#  ['ross', 'deep', 'voice', 'ill', 'whatever', 'christine'],
#  ['rachel', 'phone', 'daddy'],
#  ['cant', 'marry'],
#  ['im', 'sorry'],
#  ['dont', 'love'],
#  ['well', 'matters'],
#  ['scene', 'tv', 'changed', 'show', 'two', 'women', 'one', 'holding', 'hair'],
#  ['phoebe', 'let', 'go', 'hair', 'head', 'fall'],
#  ['chandler', 'tv', 'ooh', 'wearing', 'pants'],
#  ['joey', 'say', 'push', 'stairs'],
#  ['phoebe', 'ross', 'chandler', 'joey', 'push', 'stairs'],
#  ['push', 'stairs'],
#  ['push', 'stairs'],
#  ['pushed', 'stairs', 'everyone', 'cheers'],
#  ['rachel', 'cmon', 'daddy', 'listen'],
#  ['like', 'like', 'life', 'everyone', 'always', 'told', 'youre', 'shoe'],
#  ['youre', 'shoe', 'youre', 'shoe', 'youre', 'shoe'],
#  ['today', 'stopped', 'said', 'dont', 'wanna', 'shoe'],
#  ['wanna', 'purse', 'yknow'],
#  ['hat'],
#  ['im',
#   'saying',
#   'want',
#   'buy',
#   'hat',
#   'im',
#   'saying',
#   'ha',
#   'metaphor',
#   'daddy'],
#  ['ross', 'see', 'hed', 'trouble'],
#  ['rachel', 'look', 'daddy', 'life'],
#  ['well', 'maybe', 'ill', 'stay', 'monica'],
#  ['monica',
#   'well',
#   'guess',
#   'weve',
#   'established',
#   'whos',
#   'staying',
#   'monica',
#   'rachel',
#   'well',
#   'maybe',
#   'thats',
#   'decision'],
#  ['well', 'maybe', 'dont', 'need', 'money'],
#  ['wait'],
#  ['wait', 'said', 'maybe'],
#  ['time', 'lapse', 'rachel', 'breating', 'paper', 'bag'],
#  ['monica', 'breathe', 'breathe', 'thats'],
#  ['try',
#   'think',
#   'nice',
#   'calm',
#   'things',
#   'phoebe',
#   'sings',
#   'raindrops',
#   'roses',
#   'rabbits',
#   'kittens',
#   'rachel',
#   'monica',
#   'turn',
#   'look'],
#  ['bluebells',
#   'sleighbells',
#   'something',
#   'mittens',
#   'la',
#   'la',
#   'la',
#   'lasomething',
#   'noodles',
#   'string'],
#  ['rachel', 'im', 'better'],
#  ['phoebe', 'grins', 'walks', 'kitchen', 'says', 'chandler', 'joey'],
#  ['helped'],
#  ['monica', 'okay', 'look', 'probably', 'best', 'yknow'],
#  ['independence'],
#  ['taking', 'control', 'life'],
#  ['whole', 'hat', 'thing'],
#  ['joey', 'comforting', 'hey', 'need', 'anything', 'always', 'come', 'joey'],
#  ['chandler', 'live', 'across', 'hall'],
#  ['hes', 'away', 'lot'],
#  ['monica', 'joey', 'stop', 'hitting'],
#  ['wedding', 'day'],
#  ['joey', 'like', 'theres', 'rule', 'something'],
#  ['door', 'buzzer', 'sounds', 'chandler', 'gets'],
#  ['chandler', 'please', 'dont', 'horrible', 'sound'],
#  ['paul', 'intercom', 'uh', 'paul'],
#  ['monica', 'oh', 'god'],
#  ['buzz'],
#  ['joey', 'whos', 'paul'],
#  ['ross', 'paul', 'wine', 'guy', 'paul'],
#  ['monica', 'maybe'],
#  ['joey', 'wait'],
#  ['real', 'date', 'tonight', 'paul', 'wine', 'guy'],
#  ['ross', 'finally', 'asked'],
#  ['monica', 'yes'],
#  ['chandler', 'ooh', 'dear', 'diary', 'moment'],
#  ['monica',
#   'rach',
#   'wait',
#   'cancel',
#   'rachel',
#   'please',
#   'go',
#   'thatd',
#   'fine'],
#  ['monica', 'ross', 'okay'],
#  ['mean', 'want', 'stay'],
#  ['ross', 'choked', 'voice', 'thatd', 'good', 'monica', 'horrified', 'really'],
#  ['ross', 'normal', 'voice', 'go'],
#  ['paul', 'wine', 'guy'],
#  ['phoebe', 'mean'],
#  ['sell', 'drink', 'complain', 'lot'],
#  ['chandler', 'doesnt', 'know'],
#  ['theres', 'knock', 'door', 'paul'],
#  ['monica', 'hi', 'come'],
#  ['paul', 'lined', 'next', 'door'],
#  ['everybody', 'everybody', 'paul'],
#  ['hey'],
#  ['paul'],
#  ['hi'],
#  ['wine', 'guy'],
#  ['hey'],
#  ['chandler', 'im', 'sorry', 'didnt', 'catch', 'name'],
#  ['paul'],
#  ['monica',
#   'okay',
#   'ummumm',
#   'ill',
#   'justill',
#   'right',
#   'back',
#   'gotta',
#   'go',
#   'ah',
#   'go',
#   'ah',
#   'ross',
#   'wandering'],
#  ['monica', 'change'],
#  ['okay', 'sit'],
#  ['shows', 'paul', 'two', 'seconds'],
#  ['phoebe', 'ooh', 'pulled', 'four', 'eyelashes'],
#  ['cant', 'good'],
#  ['monica', 'goes', 'change'],
#  ['joey', 'hey', 'paul'],
#  ['paul', 'yeah'],
#  ['joey',
#   'heres',
#   'little',
#   'tip',
#   'really',
#   'likes',
#   'rub',
#   'neck',
#   'spot',
#   'starts',
#   'get',
#   'little',
#   'red'],
#  ['monica', 'yelling', 'bedroom', 'shut', 'joey'],
#  ['ross', 'rachel', 'whatre', 'uh', 'whatre', 'tonight'],
#  ['rachel',
#   'well',
#   'kinda',
#   'supposed',
#   'headed',
#   'aruba',
#   'honeymoon',
#   'nothing'],
#  ['ross',
#   'right',
#   'youre',
#   'even',
#   'getting',
#   'honeymoon',
#   'god',
#   'although',
#   'aruba',
#   'time',
#   'year',
#   'talk',
#   'thinks',
#   'big',
#   'lizards'],
#  ['anyway',
#   'dont',
#   'feel',
#   'like',
#   'alone',
#   'tonight',
#   'joey',
#   'chandler',
#   'coming',
#   'help',
#   'put',
#   'together',
#   'new',
#   'furniture'],
#  ['chandler', 'deadpan', 'yes', 'excited'],
#  ['rachel',
#   'well',
#   'actually',
#   'thanks',
#   'think',
#   'im',
#   'gonna',
#   'hang',
#   'tonight'],
#  ['kinda', 'long', 'day'],
#  ['ross', 'okay', 'sure'],
#  ['joey', 'hey', 'pheebs', 'wanna', 'help'],
#  ['phoebe', 'oh', 'wish', 'could', 'dont', 'want'],
#  ['commercial', 'break', 'scene', 'subway', 'phoebe', 'singing', 'change'],
#  ['phoebe',
#   'singing',
#   'love',
#   'sweet',
#   'summer',
#   'showers',
#   'love',
#   'wondrous',
#   'work',
#   'art',
#   'love',
#   'oh',
#   'love',
#   'loveis',
#   'like',
#   'giant',
#   'pigeoncrapping',
#   'heart'],
#  ['lalalalala', 'guy', 'gives', 'change', 'guy', 'thank'],
#  ['sings', 'lalalalaohhh'],
#  ['scene', 'rosss', 'apartment', 'guys', 'assembling', 'furniture'],
#  ['ross',
#   'squatting',
#   'reading',
#   'instructions',
#   'im',
#   'supposed',
#   'attach',
#   'brackety',
#   'thing',
#   'side',
#   'things',
#   'using',
#   'bunch',
#   'little',
#   'worm',
#   'guys'],
#  ['brackety',
#   'thing',
#   'see',
#   'whim',
#   'guys',
#   'whatsoever',
#   'cannot',
#   'feel',
#   'legs'],
#  ['joey', 'chandler', 'finishing', 'assembling', 'bookcase'],
#  ['joey', 'im', 'thinking', 'weve', 'got', 'bookcase'],
#  ['chandler', 'beautiful', 'thing'],
#  ['joey', 'picking', 'leftover', 'part', 'whats'],
#  ['chandler', 'would', 'say', 'lshaped', 'bracket'],
#  ['joey', 'goes'],
#  ['chandler', 'idea'],
#  ['joey', 'checks', 'ross', 'looking', 'dumps', 'plant'],
#  ['joey', 'done', 'bookcase'],
#  ['chandler', 'finished'],
#  ['ross', 'clutching', 'beer', 'sniffing', 'carols', 'favorite', 'beer'],
#  ['always', 'drank', 'known'],
#  ['joey', 'heyheyheyhey', 'youre', 'gonna', 'start', 'stuff', 'outta'],
#  ['chandler', 'yes', 'please', 'dont', 'spoil', 'fun'],
#  ['joey', 'ross', 'let', 'ask', 'question'],
#  ['got', 'furniture', 'stereo', 'good', 'tv', 'get'],
#  ['ross', 'guys'],
#  ['chandler', 'oh', 'god'],
#  ['joey', 'got', 'screwed'],
#  ['chandler', 'oh', 'god'],
#  ['scene', 'restaurant', 'monica', 'paul', 'eating'],
#  ['monica', 'oh', 'god'],
#  ['paul', 'know', 'know', 'im', 'idiot'],
#  ['guess',
#   'caught',
#   'started',
#   'going',
#   'dentist',
#   'four',
#   'five',
#   'times',
#   'week'],
#  ['mean', 'clean', 'teeth', 'get'],
#  ['monica', 'brothers', 'going', 'right', 'hes', 'mess'],
#  ['get'],
#  ['paul',
#   'well',
#   'might',
#   'try',
#   'accidentally',
#   'breaking',
#   'something',
#   'valuable',
#   'say',
#   'monica',
#   'leg'],
#  ['paul', 'laughing', 'thats', 'one', 'way'],
#  ['went', 'watch'],
#  ['monica', 'actually', 'broke', 'watch'],
#  ['wow'],
#  ['worst',
#   'thing',
#   'ever',
#   'ii',
#   'shredded',
#   'boyfriends',
#   'favorite',
#   'bath',
#   'towel'],
#  ['paul', 'ooh', 'steer', 'clear'],
#  ['monica', 'thats', 'right'],
#  ['scene', 'monicas', 'apartment', 'rachel', 'talking', 'phone', 'pacing'],
#  ['rachel', 'barry', 'im', 'sorry'],
#  ['sorry'],
#  ['know',
#   'probably',
#   'think',
#   'said',
#   'day',
#   'making',
#   'love',
#   'socks',
#   'isnt',
#   'isnt',
#   'ju',
#   'stops',
#   'talking',
#   'dials',
#   'phone'],
#  ['hi',
#   'machine',
#   'cut',
#   'anywaylook',
#   'look',
#   'know',
#   'girl',
#   'going',
#   'incredibly',
#   'lucky',
#   'become',
#   'mrs',
#   'barry',
#   'finkel',
#   'isnt'],
#  ['idea', 'right', 'give', 'chance', 'maching', 'cuts', 'redials'],
#  ['scene',
#   'rosss',
#   'apartment',
#   'ross',
#   'pacing',
#   'joey',
#   'chandler',
#   'working',
#   'furniture'],
#  ['ross', 'im', 'divorced'],
#  ['im', 'im', 'divorced'],
#  ['joey', 'shut'],
#  ['chandler', 'must', 'stop'],
#  ['chandler', 'hits', 'working', 'hammer', 'collapses'],
#  ['ross', 'took', 'hour'],
#  ['chandler',
#   'look',
#   'ross',
#   'gotta',
#   'understand',
#   'us',
#   'havent',
#   'relationship',
#   'lasted',
#   'longer',
#   'mento'],
#  ['however', 'love', 'woman', 'four', 'years'],
#  ['four', 'years', 'closeness', 'sharing', 'end', 'ripped', 'heart', 'dont'],
#  ['dont', 'think', 'point'],
#  ['ross', 'know', 'scariest', 'part'],
#  ['theres', 'one', 'woman', 'everybody', 'yknow'],
#  ['mean', 'get', 'one', 'woman', 'thats'],
#  ['unfortunately', 'case', 'one', 'woman', 'joey', 'talking'],
#  ['one', 'woman'],
#  ['thats', 'like', 'saying', 'theres', 'one', 'flavor', 'ice', 'cream'],
#  ['lemme', 'tell', 'something', 'ross'],
#  ['theres', 'lots', 'flavors'],
#  ['theres', 'rocky', 'road', 'cookie', 'dough', 'bing'],
#  ['cherry', 'vanilla'],
#  ['could', 'get', 'em', 'jimmies', 'nuts', 'whipped', 'cream'],
#  ['best', 'thing', 'ever', 'happened'],
#  ['got', 'married', 'like', 'eight'],
#  ['welcome', 'back', 'world'],
#  ['grab', 'spoon'],
#  ['ross', 'honestly', 'dont', 'know', 'im', 'hungry', 'horny'],
#  ['chandler', 'stay', 'freezer'],
#  ['scene', 'restaurant', 'monica', 'paul', 'still', 'eating'],
#  ['paul', 'ever', 'since', 'walked', 'uh', 'monica'],
#  ['wanna', 'spell', 'noodles'],
#  ['paul', 'fifth', 'date', 'kinda', 'revelation'],
#  ['monica', 'oh', 'gonna', 'fifth', 'date'],
#  ['paul', 'isnt'],
#  ['monica', 'yeah', 'yeah', 'think'],
#  ['gonna', 'say'],
#  ['paul',
#   'well',
#   'everev',
#   'ever',
#   'since',
#   'left',
#   'um',
#   'havent',
#   'able',
#   'uh',
#   'perform'],
#  ['monica', 'takes', 'sip', 'drink'],
#  ['sexually'],
#  ['monica', 'spitting', 'drink', 'shock', 'oh', 'god', 'oh', 'god', 'sorry'],
#  ['sorry',
#   'paul',
#   'okay',
#   'monica',
#   'know',
#   'spit',
#   'probably',
#   'need',
#   'right'],
#  ['um', 'long'],
#  ['paul', 'two', 'years'],
#  ['monica', 'wow'],
#  ['imimim', 'glad', 'smashed', 'watch'],
#  ['paul', 'still', 'think', 'um', 'might', 'want', 'fifth', 'date'],
#  ['monica', 'pauseyeah'],
#  ['yeah'],
#  ['scene',
#   'monicas',
#   'apartment',
#   'rachel',
#   'watching',
#   'joanne',
#   'loves',
#   'chaci'],
#  ['priest',
#   'tv',
#   'gathered',
#   'today',
#   'join',
#   'joanne',
#   'louise',
#   'cunningham',
#   'charles',
#   'arcola',
#   'bound',
#   'holy',
#   'matrimony'],
#  ['rachel', 'ohsee', 'joanne', 'loved', 'chachi'],
#  ['thats', 'difference'],
#  ['scene', 'rosss', 'apartment', 'theyre', 'sitting', 'around', 'talking'],
#  ['ross', 'scornful', 'grab', 'spoon'],
#  ['know', 'long', 'since', 'ive', 'grabbed', 'spoon'],
#  ['words', 'billy', 'dont', 'hero', 'mean', 'anything'],
#  ['joey', 'great', 'story'],
#  ['uh',
#   'gotta',
#   'go',
#   'got',
#   'date',
#   'oh',
#   'man',
#   'looks',
#   'chandler',
#   'chandler',
#   'angelas',
#   'screamer',
#   'andrea',
#   'cats'],
#  ['joey', 'right'],
#  ['thanks'],
#  ['june'],
#  ['im', 'outta'],
#  ['exits'],
#  ['ross', 'yknow', 'heres', 'thing'],
#  ['even',
#   'could',
#   'get',
#   'together',
#   'enough',
#   'ask',
#   'woman',
#   'gonna',
#   'ask'],
#  ['gazes', 'window'],
#  ['cut', 'rachel', 'staring', 'window'],
#  ['commercial',
#   'break',
#   'scene',
#   'monicas',
#   'apartment',
#   'rachel',
#   'making',
#   'coffee',
#   'joey',
#   'chandler'],
#  ['rachel', 'isnt', 'amazing'],
#  ['mean', 'never', 'made', 'coffee', 'entire', 'life'],
#  ['chandler', 'amazing'],
#  ['joey', 'congratulations'],
#  ['rachel', 'yknow', 'figure', 'make', 'coffee', 'isnt', 'anything', 'cant'],
#  ['chandler', 'invade', 'poland', 'isnt', 'anything', 'cant'],
#  ['joey',
#   'listen',
#   'youre',
#   'roll',
#   'feel',
#   'like',
#   'gotta',
#   'make',
#   'like',
#   'western',
#   'omelet',
#   'something',
#   'joey',
#   'chandler',
#   'taste',
#   'coffee',
#   'grimace',
#   'pour',
#   'plant',
#   'pot'],
#  ['although',
#   'actually',
#   'im',
#   'really',
#   'hungry',
#   'monica',
#   'entering',
#   'oh',
#   'good',
#   'lenny',
#   'squigy'],
#  ['morning'],
#  ['good', 'morning'],
#  ['paul', 'entering', 'monicas', 'room', 'morning'],
#  ['joey', 'morning', 'paul'],
#  ['rachel', 'hello', 'paul'],
#  ['chandler', 'hi', 'paul'],
#  ['monica',
#   'paul',
#   'walk',
#   'door',
#   'talk',
#   'low',
#   'voice',
#   'others',
#   'cant',
#   'hear'],
#  ['others', 'move', 'monicas', 'table', 'closer', 'door'],
#  ['paul', 'thank'],
#  ['thank', 'much'],
#  ['monica', 'stop'],
#  ['paul',
#   'im',
#   'telling',
#   'last',
#   'night',
#   'like',
#   'umm',
#   'birthdays',
#   'graduations',
#   'plus',
#   'barn',
#   'raising',
#   'scene',
#   'witness'],
#  ['monica', 'well', 'talk', 'later'],
#  ['paul', 'yeah'],
#  ['kiss', 'thank'],
#  ['exits', 'joey', 'wasnt', 'real', 'date'],
#  ['hell', 'real', 'date'],
#  ['monica', 'shut', 'put', 'table', 'back'],
#  ['okayyy'],
#  ['chandler', 'right', 'kids', 'gotta', 'get', 'work'],
#  ['dont',
#   'input',
#   'numbers',
#   'doesnt',
#   'make',
#   'much',
#   'difference',
#   'rachel',
#   'like',
#   'guys',
#   'jobs'],
#  ['monica', 'yeah', 'jobs'],
#  ['see', 'thats', 'buy', 'stuff'],
#  ['joey', 'yeah', 'im', 'actor'],
#  ['rachel', 'wow'],
#  ['would', 'seen', 'anything'],
#  ['joey', 'doubt'],
#  ['mostly', 'regional', 'work'],
#  ['monica',
#   'oh',
#   'wait',
#   'wait',
#   'unless',
#   'happened',
#   'catch',
#   'reruns',
#   'production',
#   'pinocchio',
#   'little',
#   'theater',
#   'park'],
#  ['joey', 'look', 'job', 'right'],
#  ['chandler', 'look', 'gippetto', 'im', 'real', 'live', 'boy'],
#  ['joey', 'take', 'abuse'],
#  ['walks', 'door', 'opens', 'leave'],
#  ['chandler', 'youre', 'right', 'im', 'sorry'],
#  ['burst', 'song', 'dances', 'door'],
#  ['wooden',
#   'boy',
#   'little',
#   'wooden',
#   'boy',
#   'joey',
#   'know',
#   'hes',
#   'dead',
#   'man'],
#  ['oh', 'chandler'],
#  ['starts', 'chandler'],
#  ['monica', 'today'],
#  ['sleep', 'okay'],
#  ['talk', 'barry'],
#  ['cant', 'stop', 'smiling'],
#  ['rachel', 'see'],
#  ['look', 'like', 'slept', 'hanger', 'mouth'],
#  ['monica', 'know', 'hes', 'remember', 'tony', 'demarco'],
#  ['rachel', 'oh', 'yeah'],
#  ['monica', 'well', 'like'],
#  ['feelings'],
#  ['rachel', 'oh', 'wow'],
#  ['trouble'],
#  ['monica', 'big', 'time'],
#  ['rachel', 'want', 'wedding', 'dress'],
#  ['hardly', 'used'],
#  ['monica', 'think', 'getting', 'little', 'ahead', 'selves'],
#  ['okay'],
#  ['okay'],
#  ['going', 'get', 'go', 'work', 'think', 'day'],
#  ['else', 'im', 'gonna', 'get', 'go', 'work'],
#  ['rachel', 'oh', 'look', 'wish', 'luck'],
#  ['monica'],
#  ['rachel', 'im', 'gonna', 'go', 'get', 'one', 'thinks', 'job', 'things'],
#  ['monica', 'exits'],
#  ['scene', 'iridium', 'monica', 'working', 'frannie', 'enters'],
#  ['frannie', 'hey', 'monica'],
#  ['monica', 'hey', 'frannie', 'welcome', 'back'],
#  ['florida'],
#  ['frannie', 'sex', 'didnt'],
#  ['monica'],
#  ['frannie',
#   'oh',
#   'hate',
#   'im',
#   'pushing',
#   'aunt',
#   'roz',
#   'parrot',
#   'jungle',
#   'youre',
#   'sex'],
#  ['monica', 'know', 'paul'],
#  ['frannie', 'paul', 'wine', 'guy'],
#  ['oh', 'yeah', 'know', 'paul'],
#  ['monica', 'mean', 'know', 'paul', 'like', 'know', 'paul'],
#  ['frannie', 'kidding'],
#  ['take', 'credit', 'paul'],
#  ['yknow', 'snap', 'turtle', 'two', 'years'],
#  ['scene', 'central', 'perk', 'everyone', 'rachel'],
#  ['joey', 'sitting', 'arm', 'couchof', 'course', 'line'],
#  ['monica'],
#  ['would', 'anybody', 'something', 'like'],
#  ['ross', 'assume', 'looking', 'answer', 'sophisticated', 'get', 'bed'],
#  ['monica', 'hate', 'men'],
#  ['hate', 'men'],
#  ['phoebe', 'oh', 'dont', 'hate', 'dont', 'want', 'put', 'universe'],
#  ['monica'],
#  ['like',
#   'sort',
#   'beacon',
#   'dogs',
#   'men',
#   'severe',
#   'emotional',
#   'problems',
#   'hear'],
#  ['phoebe', 'right', 'cmere', 'gimme', 'feet'],
#  ['starts', 'massaging'],
#  ['monica', 'thought', 'nice', 'yknow'],
#  ['joey', 'bursts', 'laughing', 'cant', 'believe', 'didnt', 'know', 'line'],
#  ['monica', 'pushes', 'sofa', 'rachel', 'enters', 'shopping', 'bag'],
#  ['rachel', 'guess'],
#  ['ross', 'got', 'job'],
#  ['rachel', 'kidding'],
#  ['im', 'trained', 'nothing'],
#  ['laughed', 'twelve', 'interviews', 'today'],
#  ['chandler', 'yet', 'youre', 'surprisingly', 'upbeat'],
#  ['rachel',
#   'would',
#   'found',
#   'john',
#   'david',
#   'boots',
#   'sale',
#   'fifty',
#   'percent'],
#  ['chandler',
#   'oh',
#   'well',
#   'know',
#   'rachel',
#   'theyre',
#   'new',
#   'dont',
#   'need',
#   'job',
#   'dont',
#   'need',
#   'parents',
#   'ive',
#   'got',
#   'great',
#   'boots',
#   'boots'],
#  ['monica', 'howd', 'pay'],
#  ['rachel', 'uh', 'credit', 'card'],
#  ['monica', 'pays'],
#  ['rachel', 'um', 'father'],
#  ['scene',
#   'monica',
#   'rachels',
#   'everyone',
#   'sitting',
#   'around',
#   'kitchen',
#   'table'],
#  ['rachels',
#   'credit',
#   'cards',
#   'spread',
#   'table',
#   'along',
#   'pair',
#   'scissors'],
#  ['rachel', 'oh', 'god', 'come', 'guys', 'really', 'necessary'],
#  ['mean', 'stop', 'charging', 'anytime', 'want'],
#  ['monica', 'cmon', 'cant', 'live', 'parents', 'whole', 'life'],
#  ['rachel', 'know'],
#  ['thats', 'getting', 'married'],
#  ['phoebe', 'give', 'break', 'hard', 'first', 'time'],
#  ['rachel', 'thank'],
#  ['phoebe', 'youre', 'welcome'],
#  ['remember', 'first', 'came', 'city'],
#  ['fourteen'],
#  ['mom',
#   'killed',
#   'stepdad',
#   'back',
#   'prison',
#   'got',
#   'didnt',
#   'know',
#   'anybody'],
#  ['ended',
#   'living',
#   'albino',
#   'guy',
#   'like',
#   'cleaning',
#   'windshields',
#   'outside',
#   'port',
#   'authority',
#   'killed',
#   'found',
#   'aromatherapy'],
#  ['believe', 'know', 'exactly', 'feel'],
#  ['pause',
#   'ross',
#   'word',
#   'youre',
#   'looking',
#   'anyway',
#   'monica',
#   'right',
#   'ready'],
#  ['rachel'],
#  ['im', 'ready'],
#  ['ready'],
#  ['hey', 'rach'],
#  ['ready', 'jump', 'airplane', 'without', 'parachute'],
#  ['come', 'cant'],
#  ['monica', 'know'],
#  ['rachel', 'dont', 'think'],
#  ['ross', 'come', 'made', 'coffee'],
#  ['anything'],
#  ['chandler',
#   'slowly',
#   'tries',
#   'hide',
#   'dead',
#   'plant',
#   'morning',
#   'joey',
#   'poured',
#   'coffee'],
#  ['ross', 'cmon', 'cut'],
#  ['cut',
#   'cut',
#   'cut',
#   'cut',
#   'cut',
#   'cut',
#   'cut',
#   'cut',
#   'cut',
#   'cut',
#   'cuts',
#   'one',
#   'cheer'],
#  ['rachel', 'yknow'],
#  ['think', 'leave'],
#  ['kinda', 'like', 'symbolic', 'gesture', 'monica', 'rachel'],
#  ['library', 'card'],
#  ['cut',
#   'cut',
#   'cut',
#   'cut',
#   'cut',
#   'cut',
#   'cut',
#   'chandler',
#   'rachel',
#   'cutting',
#   'cards',
#   'yknow',
#   'listen',
#   'closely',
#   'hear',
#   'thousand',
#   'retailers',
#   'scream'],
#  ['finishes', 'cutting', 'cheer'],
#  ['monica', 'welcome', 'real', 'world'],
#  ['sucks'],
#  ['youre', 'gonna', 'love'],
#  ['time',
#   'lapse',
#   'rachel',
#   'ross',
#   'watching',
#   'tv',
#   'channel',
#   'finishes',
#   'broadcast',
#   'day',
#   'playing',
#   'national',
#   'anthem'],
#  ['monica', 'well', 'thats', 'ross', 'gonna', 'crash', 'couch'],
#  ['ross'],
#  ['gotta', 'go', 'home', 'sometime'],
#  ['monica', 'okay'],
#  ['ross', 'yeah'],
#  ['rachel', 'hey', 'mon', 'look', 'found', 'floor'],
#  ['monica', 'smiles'],
#  ['monica', 'thats', 'pauls', 'watch'],
#  ['put', 'back', 'found'],
#  ['oh', 'boy'],
#  ['alright'],
#  ['goodnight', 'everybody'],
#  ['ross', 'rachel', 'goodnight'],
#  ['monica', 'stomps', 'pauls', 'watch', 'goes', 'room'],
#  ['ross', 'mmm'],
#  ['reach',
#   'last',
#   'cookie',
#   'oh',
#   'rachel',
#   'sorry',
#   'ross',
#   'go',
#   'rachel',
#   'really',
#   'dont',
#   'want',
#   'ross',
#   'split'],
#  ['rachel', 'okay'],
#  ['ross', 'okay'],
#  ['split'],
#  ['know',
#   'probably',
#   'didnt',
#   'know',
#   'back',
#   'high',
#   'school',
#   'um',
#   'major',
#   'crush'],
#  ['rachel', 'knew'],
#  ['ross'],
#  ['oh'],
#  ['always', 'figured', 'thought', 'monicas', 'geeky', 'older', 'brother'],
#  ['rachel'],
#  ['ross', 'oh'],
#  ['listen',
#   'think',
#   'try',
#   'let',
#   'intense',
#   'vulnerability',
#   'become',
#   'kind',
#   'factor',
#   'think',
#   'would',
#   'okay',
#   'asked'],
#  ['sometime'],
#  ['maybe'],
#  ['rachel',
#   'yeah',
#   'maybe',
#   'ross',
#   'okay',
#   'okay',
#   'maybe',
#   'rachel',
#   'goodnight'],
#  ['ross', 'goodnight'],
#  ['rachel',
#   'goes',
#   'room',
#   'monica',
#   'enters',
#   'living',
#   'room',
#   'ross',
#   'leaving'],
#  ['monica', 'see', 'ya', 'waitwait', 'whats'],
#  ['ross', 'grabbed', 'spoon'],
#  ['ross', 'exits', 'monica', 'idea', 'means'],
#  ['closing', 'credits', 'scene', 'central', 'perk', 'everyone'],
#  ['joey', 'cant', 'believe', 'im', 'hearing'],
#  ['phoebe', 'sings', 'cant', 'believe', 'im', 'hearing', 'monica'],
#  ['ii',
#   'said',
#   'phoebe',
#   'sings',
#   'said',
#   'monica',
#   'phoebe',
#   'would',
#   'stop'],
#  ['phoebe', 'oh'],
#  ['yes'],
#  ['monica', 'said', 'nice', 'butt', 'great', 'butt'],
#  ['joey', 'oh', 'wouldnt', 'know', 'great', 'butt', 'came', 'bit', 'ya'],
#  ['ross', 'theres', 'image'],
#  ['rachel', 'walks', 'pot', 'coffee', 'would', 'anybody', 'like', 'coffee'],
#  ['chandler', 'make', 'serving'],
#  ['rachel', 'im', 'serving'],
#  ['yeah'],
#  ['yeah', 'ill', 'cup', 'coffee'],
#  ['chandler', 'kids', 'new', 'dream'],
#  ['im', 'las', 'vegas'],
#  ['rachel', 'sits', 'hear', 'chandlers', 'dream'],
#  ['customer', 'rachel', 'ahh', 'miss'],
#  ['coffee'],
#  ['rachel', 'ugh'],
#  ['another', 'customer', 'thats', 'leaving'],
#  ['excuse', 'could', 'give', 'guy'],
#  ['hands', 'coffee', 'pot'],
#  ['go', 'ahead'],
#  ['thank'],
#  ['gang'],
#  ['sorry'],
#  ['okay', 'las', 'vegas'],
#  ['chandler', 'okay', 'im', 'las', 'vegas'],
#  ['im',
#   'liza',
#   'minelli',
#   'end',
#   'one',
#   'sonogram',
#   'end',
#   'written',
#   'marta',
#   'kauffman',
#   'david',
#   'crane',
#   'scene',
#   'central',
#   'perk',
#   'everyones'],
#  ['monica',
#   'guys',
#   'dont',
#   'understand',
#   'us',
#   'kissing',
#   'important',
#   'part'],
#  ['joey', 'yeah', 'rightyserious'],
#  ['phoebe', 'oh', 'yeah'],
#  ['rachel', 'everything', 'need', 'know', 'first', 'kiss'],
#  ['monica', 'absolutely'],
#  ['chandler',
#   'yeah',
#   'think',
#   'us',
#   'kissing',
#   'pretty',
#   'much',
#   'like',
#   'opening',
#   'act',
#   'yknow'],
#  ['mean', 'like', 'standup', 'comedian', 'sit', 'pink', 'floyd', 'comes'],
#  ['ross',
#   'yeah',
#   'andand',
#   'dont',
#   'like',
#   'comedian',
#   'thatthat',
#   'thats',
#   'bought',
#   'ticket'],
#  ['chandler',
#   'problem',
#   'though',
#   'concerts',
#   'matter',
#   'great',
#   'show',
#   'girls',
#   'always',
#   'looking',
#   'comedian',
#   'yknow'],
#  ['mean',
#   'car',
#   'fighting',
#   'traffic',
#   'basically',
#   'trying',
#   'stay',
#   'awake'],
#  ['rachel', 'yeah', 'well', 'word', 'advice', 'bring', 'back', 'comedian'],
#  ['otherwise',
#   'next',
#   'time',
#   'youre',
#   'gonna',
#   'find',
#   'sitting',
#   'home',
#   'listening',
#   'album',
#   'alone'],
#  ['joey', 'pauseare', 'still', 'talking', 'sex'],
#  ['opening',
#   'credits',
#   'scene',
#   'museum',
#   'prehistoric',
#   'history',
#   'ross',
#   'coworker',
#   'marsha',
#   'setting',
#   'exhibit',
#   'includes',
#   'mannequins',
#   'cave',
#   'people'],
#  ['ross', 'good', 'good', 'mm', 'doesnt', 'seem', 'little', 'angry'],
#  ['marsha', 'well', 'issues'],
#  ['ross'],
#  ['marsha',
#   'hes',
#   'banging',
#   'women',
#   'head',
#   'club',
#   'sits',
#   'home',
#   'trying',
#   'get',
#   'mastodon',
#   'smell',
#   'carpet'],
#  ['ross', 'marsha', 'cave', 'people'],
#  ['okay'],
#  ['issues', 'like', 'gee', 'glaciers', 'getting', 'kinda', 'close'],
#  ['see'],
#  ['marsha', 'speaking', 'issues', 'isnt', 'exwife'],
#  ['carol',
#   'rosss',
#   'exwife',
#   'entered',
#   'behind',
#   'standing',
#   'outstide',
#   'exhibit'],
#  ['ross', 'trying', 'ignore'],
#  ['marsha', 'yes'],
#  ['carol'],
#  ['hi'],
#  ['ross', 'okay', 'okay', 'yes'],
#  ['waves', 'ill', 'uh', 'catch', 'ice', 'age'],
#  ['marsha', 'extis', 'ross', 'waves', 'carol', 'exhibit'],
#  ['rosshi'],
#  ['carol'],
#  ['ross', 'look', 'great'],
#  ['uh'],
#  ['hate'],
#  ['carol', 'sorry'],
#  ['look', 'good'],
#  ['ross', 'ah', 'well', 'anyone', 'stands', 'erect'],
#  ['whats', 'new'],
#  ['still', 'uh', 'carol', 'lesbian'],
#  ['ross', 'well', 'never', 'know'],
#  ['hows', 'um', 'hows', 'family'],
#  ['carol', 'martys', 'still', 'totally', 'paranoid'],
#  ['oh', 'uh', 'ross', 'carol'],
#  ['carol', 'im', 'pregnant'],
#  ['ross', 'pregnant'],
#  ['scene',
#   'monica',
#   'rachels',
#   'chandler',
#   'joey',
#   'phoebe',
#   'monica',
#   'watching',
#   'threes',
#   'company'],
#  ['chandler', 'oh', 'think', 'episode', 'threes', 'company', 'theres', 'kind'],
#  ['phoebethen', 'ive', 'already', 'seen', 'one'],
#  ['turns', 'tv'],
#  ['monica', 'taking', 'drink', 'joey'],
#  ['joey', 'yeah', 'sorry', 'swallowing', 'slowed'],
#  ['monica', 'whose', 'little', 'ball', 'paper'],
#  ['chandler', 'oh', 'uh', 'would', 'mine'],
#  ['see',
#   'wrote',
#   'note',
#   'realised',
#   'didnt',
#   'need',
#   'balled',
#   'sees',
#   'monica',
#   'glaring',
#   'wish',
#   'dead'],
#  ['monica', 'starts', 'fluff', 'pillow'],
#  ['phoebe',
#   'shes',
#   'already',
#   'fluffed',
#   'pillow',
#   'monica',
#   'know',
#   'youve',
#   'already',
#   'fluffed',
#   'monica',
#   'glares'],
#  ['fine'],
#  ['monica',
#   'look',
#   'im',
#   'sorry',
#   'guys',
#   'dont',
#   'wanna',
#   'give',
#   'ammunition',
#   'already'],
#  ['chandler',
#   'yes',
#   'know',
#   'cruel',
#   'parent',
#   'flatness',
#   'childs',
#   'pillow'],
#  ['phoebe', 'monica', 'hi'],
#  ['um', 'monica', 'youre', 'scaring'],
#  ['mean', 'youre', 'like', 'youre', 'like', 'chaotic', 'twirly'],
#  ['notnot', 'good', 'way'],
#  ['joey', 'yeah', 'calm'],
#  ['dont',
#   'see',
#   'ross',
#   'getting',
#   'chaotic',
#   'twirly',
#   'every',
#   'time',
#   'come'],
#  ['monica', 'thats', 'far', 'parents', 'concerned', 'ross', 'wrong'],
#  ['ysee', 'hes', 'prince'],
#  ['apparently', 'big', 'ceremony', 'born'],
#  ['chandler',
#   'looking',
#   'window',
#   'ew',
#   'ew',
#   'ew',
#   'ew',
#   'ew',
#   'ew',
#   'ew',
#   'ew'],
#  ['monica'],
#  ['chandler', 'ugly', 'naked', 'guy', 'got', 'thighmaster'],
#  ['eeaagh'],
#  ['rachel', 'enters', 'room'],
#  ['rachel', 'anybody', 'seen', 'engagement', 'ring'],
#  ['phoebe', 'yeah', 'beautiful'],
#  ['rachel',
#   'oh',
#   'god',
#   'oh',
#   'god',
#   'oh',
#   'god',
#   'oh',
#   'god',
#   'oh',
#   'god',
#   'oh',
#   'god',
#   'starts',
#   'look',
#   'couch',
#   'cushions'],
#  ['phoebe', 'look', 'dont', 'touch'],
#  ['rachel',
#   'oh',
#   'like',
#   'wasnt',
#   'dreading',
#   'tomorrow',
#   'enough',
#   'give',
#   'back',
#   'hi',
#   'barry'],
#  ['remember'],
#  ['im', 'girl', 'veil', 'stomped', 'heart', 'front', 'entire', 'family'],
#  ['oh',
#   'god',
#   'im',
#   'gonna',
#   'return',
#   'ring',
#   'without',
#   'ring',
#   'makes',
#   'much',
#   'harder',
#   'monica',
#   'easy',
#   'rach',
#   'well',
#   'find'],
#  ['wont'],
#  ['chandler', 'joey', 'oh'],
#  ['yeah'],
#  ['joey', 'alright', 'whendya', 'last'],
#  ['phoebe', 'doy'],
#  ['probably', 'right', 'lost'],
#  ['chandler',
#   'dont',
#   'get',
#   'lot',
#   'doy',
#   'days',
#   'rachel',
#   'know',
#   'morning',
#   'know',
#   'kitchen',
#   'chandler',
#   'dinah'],
#  ['rachel',
#   'looks',
#   'lasagne',
#   'realizes',
#   'something',
#   'ohhhhh',
#   'dont',
#   'mad',
#   'monica',
#   'didnt'],
#  ['rachel', 'oh', 'sorry', 'monica', 'gave', 'one', 'job'],
#  ['starts', 'examin', 'lasagne', 'bottom', 'glass', 'pan'],
#  ['rachel', 'oh', 'look', 'straight', 'noodles'],
#  ['chandler',
#   'monica',
#   'know',
#   'thats',
#   'look',
#   'engagement',
#   'ring',
#   'lasagne',
#   'monica',
#   'puts',
#   'lasagne',
#   'cant'],
#  ['chandler', 'boys'],
#  ['going'],
#  ['chandler',
#   'joey',
#   'phoebe',
#   'start',
#   'pick',
#   'lasagne',
#   'theres',
#   'knock',
#   'door',
#   'monica',
#   'answers'],
#  ['ross', 'standing', 'outside', 'doorhi'],
#  ['monica', 'wow'],
#  ['happy', 'hi'],
#  ['ross', 'carols', 'pregnant'],
#  ['phoebe', 'everyone', 'else', 'stunned', 'ooh'],
#  ['found'],
#  ['monica', 'wwwh', 'wha', 'www', 'ross', 'yeah'],
#  ['another', 'two', 'hours', 'might', 'right'],
#  ['enters'],
#  ['chandler',
#   'kinda',
#   'puts',
#   'whole',
#   'pillow',
#   'thing',
#   'perspective',
#   'huh',
#   'mon'],
#  ['rachel', 'well', 'howhow', 'fit', 'whole', 'thing'],
#  ['ross',
#   'well',
#   'carol',
#   'says',
#   'susan',
#   'want',
#   'involved',
#   'im',
#   'comfortable',
#   'dont',
#   'involved',
#   'basically',
#   'entirely'],
#  ['phoebe', 'great'],
#  ['miss'],
#  ['monica', 'mean', 'involved'],
#  ['chandler', 'mean', 'presumably', 'biggest', 'part', 'job', 'done'],
#  ['ross', 'anyway', 'want', 'go', 'sonogram', 'thing', 'tomorrow'],
#  ['rachel', 'gonna'],
#  ['ross', 'idea'],
#  ['matter', 'though', 'im', 'still', 'gonna', 'father'],
#  ['joey', 'starts', 'eat', 'rest', 'lasagne', 'everyone', 'turns', 'stares'],
#  ['joey', 'well', 'still', 'ruined', 'right'],
#  ['scene',
#   'monica',
#   'rachels',
#   'monica',
#   'ross',
#   'pouring',
#   'wine',
#   'parents'],
#  ['mrs', 'geller', 'oh', 'martha', 'ludwins', 'daughter', 'gonna', 'call'],
#  ['tastes', 'snack', 'mmm'],
#  ['whats', 'curry', 'taste'],
#  ['monica', 'curry'],
#  ['mrs', 'geller', 'mmmm'],
#  ['ross', 'think', 'theyre', 'great'],
#  ['really'],
#  ['mr', 'geller', 'ross', 'remember', 'ludwins'],
#  ['big', 'one', 'thing', 'didnt'],
#  ['mrs', 'geller', 'thing'],
#  ['ross', 'aw', 'mom', 'monica', 'im', 'sorry', 'girl', 'going', 'call'],
#  ['mrs', 'geller', 'oh', 'graduated', 'wants', 'something', 'cooking', 'food'],
#  ['dont', 'know'],
#  ['anyway',
#   'told',
#   'restaurant',
#   'monica',
#   'mom',
#   'dont',
#   'restaurant',
#   'work',
#   'restaurant'],
#  ['mrs',
#   'geller',
#   'well',
#   'dont',
#   'know',
#   'starts',
#   'fluff',
#   'pillow',
#   'monica',
#   'fluffed',
#   'multiple',
#   'times',
#   'earlier'],
#  ['monica', 'ross', 'could', 'come', 'help', 'spaghetti', 'please'],
#  ['ross', 'yeah'],
#  ['go', 'kitchen'],
#  ['mrs', 'geller', 'oh', 'spaghetti'],
#  ['thats', 'easy'],
#  ['monica',
#   'know',
#   'going',
#   'sound',
#   'unbelievably',
#   'selfish',
#   'planning',
#   'bringing',
#   'whole',
#   'babylesbian',
#   'thing'],
#  ['think', 'might', 'take', 'heat'],
#  ['time', 'lapse', 'everyone', 'eating'],
#  ['mrs',
#   'geller',
#   'rachel',
#   'life',
#   'ran',
#   'parents',
#   'club',
#   'playing',
#   'well'],
#  ['mr',
#   'geller',
#   'im',
#   'gonna',
#   'tell',
#   'spent',
#   'wedding',
#   'forty',
#   'thousand',
#   'dollars',
#   'lot',
#   'money'],
#  ['mrs',
#   'geller',
#   'well',
#   'least',
#   'chance',
#   'leave',
#   'man',
#   'altar',
#   'monica',
#   'whats',
#   'supposed',
#   'mean'],
#  ['mrs', 'geller', 'nothing'],
#  ['expression'],
#  ['monica'],
#  ['mr', 'geller', 'dont', 'listen', 'mother'],
#  ['youre', 'independent', 'always'],
#  ['even', 'kid', 'chubby', 'friends', 'fine'],
#  ['would', 'read', 'alone', 'room', 'puzzles', 'time', 'lapse'],
#  ['mr',
#   'geller',
#   'look',
#   'people',
#   'like',
#   'ross',
#   'need',
#   'shoot',
#   'stars',
#   'museum',
#   'papers',
#   'getting',
#   'published'],
#  ['people',
#   'satisfied',
#   'staying',
#   'im',
#   'telling',
#   'people',
#   'never',
#   'get',
#   'cancer'],
#  ['time', 'lapse'],
#  ['mr',
#   'geller',
#   'read',
#   'women',
#   'trying',
#   'thank',
#   'god',
#   'little',
#   'harmonica',
#   'doesnt',
#   'seem',
#   'problem'],
#  ['monica',
#   'trying',
#   'desperately',
#   'change',
#   'subject',
#   'ross',
#   'whats',
#   'going'],
#  ['stories'],
#  ['digs', 'elbow', 'hand'],
#  ['news', 'little', 'anecdotes', 'share', 'folks'],
#  ['ross', 'pulls', 'hand', 'away', 'okay'],
#  ['okay'],
#  ['parents',
#   'look',
#   'uh',
#   'realise',
#   'guys',
#   'wondering',
#   'exactly',
#   'happened',
#   'carol',
#   'well',
#   'heres',
#   'deal'],
#  ['carols', 'lesbian'],
#  ['shes', 'living', 'woman', 'named', 'susan'],
#  ['shes', 'pregnant', 'child', 'susan', 'going', 'raise', 'baby'],
#  ['stunned', 'silence', 'ensues'],
#  ['mrs', 'geller', 'monica', 'knew'],
#  ['commercial', 'break', 'scene', 'central', 'park', 'everyones'],
#  ['joey', 'folks', 'really', 'bad', 'huh'],
#  ['ross', 'well', 'yknow', 'people', 'pros'],
#  ['know', 'theyre', 'take', 'time', 'get', 'job', 'done'],
#  ['monica',
#   'boy',
#   'know',
#   'say',
#   'cant',
#   'change',
#   'parents',
#   'boy',
#   'could',
#   'ross',
#   'id',
#   'want'],
#  ['ross', 'must', 'pee'],
#  ['goes', 'pee'],
#  ['phoebe', 'yknow', 'even', 'worse', 'youre', 'twins'],
#  ['rachel', 'youre', 'twins'],
#  ['phoebe', 'yeah'],
#  ['dont', 'speak'],
#  ['shes', 'like', 'highpowered', 'driven', 'career', 'type'],
#  ['chandler'],
#  ['phoebe', 'shes', 'waitress'],
#  ['rachel', 'right', 'guys', 'kinda', 'gotta', 'clean'],
#  ['start', 'leave'],
#  ['monica', 'chandler', 'youre', 'child', 'right'],
#  ['dont'],
#  ['chandler',
#   'well',
#   'although',
#   'imaginary',
#   'friend',
#   'parents',
#   'actually',
#   'preferred'],
#  ['rachel',
#   'lights',
#   'please',
#   'joey',
#   'turns',
#   'lights',
#   'leave',
#   'rachel',
#   'starts',
#   'clean'],
#  ['ross', 'enters', 'bathroom'],
#  ['ross', 'long'],
#  ['rachel', 'im', 'cleaning'],
#  ['ross', 'dya', 'uh', 'dya', 'need', 'help'],
#  ['rachel', 'uh', 'okay', 'sure'],
#  ['thanks'],
#  ['hands', 'broom', 'sits'],
#  ['ross', 'anyway', 'um', 'starts', 'sweep'],
#  ['uh', 'nervous', 'barry', 'tomorrow'],
#  ['rachel', 'oh', 'little', 'ross', 'mmhmm', 'rachel', 'lot'],
#  ['ross', 'mm'],
#  ['rachel', 'got', 'advice'],
#  ['yknow', 'someone', 'whos', 'recently', 'dumped'],
#  ['ross', 'well', 'may', 'wanna', 'steer', 'clear', 'word', 'dumped'],
#  ['chances',
#   'hes',
#   'gonna',
#   'broken',
#   'shell',
#   'man',
#   'yknow',
#   'try',
#   'look',
#   'terrific',
#   'know',
#   'itll',
#   'hard'],
#  ['yknow',
#   'uh',
#   'hey',
#   'ill',
#   'go',
#   'ill',
#   'give',
#   'barry',
#   'back',
#   'ring',
#   'go',
#   'carol',
#   'susan',
#   'obgyn',
#   'rachel',
#   'oh',
#   'youve',
#   'got',
#   'carol',
#   'tomorrow'],
#  ['get', 'complicated'],
#  ['ross', 'got'],
#  ['rachel', 'remember', 'high', 'school', 'together'],
#  ['ross', 'yeah'],
#  ['rachel',
#   'mean',
#   'didnt',
#   'think',
#   'gonna',
#   'meet',
#   'somone',
#   'fall',
#   'love',
#   'thatd'],
#  ['ross', 'gazes'],
#  ['ross'],
#  ['ross', 'yes', 'yes'],
#  ['rachel', 'oh'],
#  ['man', 'never', 'thought', 'id', 'leans', 'back', 'onto', 'hand'],
#  ['ross', 'either', 'pulls', 'stool', 'doesnt', 'move', 'hand'],
#  ['scene', 'carols', 'obgyn', 'carol', 'waiting'],
#  ['ross', 'entering', 'sorry', 'im', 'late', 'stuck', 'work'],
#  ['big', 'dinosaur', 'thing', 'anyway'],
#  ['susan', 'enters', 'holding', 'drink'],
#  ['susan', 'hi'],
#  ['carol', 'ross', 'remember', 'susan'],
#  ['ross', 'could', 'forget'],
#  ['susan', 'ross'],
#  ['ross', 'shake', 'hands', 'hello', 'susan'],
#  ['carol', 'good', 'shake'],
#  ['good', 'shake'],
#  ['uh', 'waiting'],
#  ['carol', 'dr', 'oberman'],
#  ['ross', 'dr', 'oberman'],
#  ['okay'],
#  ['susan'],
#  ['ross', 'course', 'uh', 'familiar', 'special', 'situation'],
#  ['carol', 'yes', 'shes', 'supportive'],
#  ['ross', 'okay', 'thats', 'great'],
#  ['susan', 'gives', 'drink', 'carol'],
#  ['im', 'oh'],
#  ['carol', 'thanks'],
#  ['ross',
#   'picks',
#   'surgical',
#   'instrament',
#   'mimes',
#   'duck',
#   'quack',
#   'quack',
#   'carol',
#   'ross'],
#  ['opens', 'cervix'],
#  ['drops', 'horror'],
#  ['scene',
#   'barrys',
#   'office',
#   'barry',
#   'working',
#   'patient',
#   'robbie',
#   'rachel',
#   'enters'],
#  ['rachel', 'barry'],
#  ['barry', 'cmon'],
#  ['rachel', 'hesitates', 'sure'],
#  ['barry', 'yeah'],
#  ['fine', 'fine'],
#  ['robbies', 'gonna', 'hours'],
#  ['robbie', 'huh'],
#  ['barry', 'ya', 'doin'],
#  ['rachel', 'im', 'uh', 'im', 'okay', 'look', 'great'],
#  ['barry',
#   'yeah',
#   'well',
#   'bernice',
#   'intercom',
#   'dr',
#   'farber',
#   'jason',
#   'greensteins',
#   'gagging'],
#  ['barry', 'answering', 'intercom', 'right'],
#  ['robbie', 'rachel', 'back', 'sec'],
#  ['barry', 'exits', 'robbie', 'stares', 'rachel'],
#  ['rachel', 'dumped'],
#  ['robbie', 'okay'],
#  ['scene', 'carols', 'obgyn', 'theyre', 'talking', 'going', 'work'],
#  ['ross', 'um', 'hows', 'uh', 'hows', 'gonna', 'work'],
#  ['yknow', 'us'],
#  ['yknow', 'like', 'important', 'decisions', 'made'],
#  ['carol', 'give', 'instance'],
#  ['ross',
#   'well',
#   'uh',
#   'uh',
#   'dont',
#   'know',
#   'okay',
#   'okay',
#   'uh',
#   'babys',
#   'name'],
#  ['carol', 'marlon', 'ross', 'marlon'],
#  ['carol', 'boy', 'minnie', 'girl'],
#  ['ross', 'mouse'],
#  ['carol', 'grandmother'],
#  ['ross', 'still', 'say', 'minnie', 'hear', 'mouse'],
#  ['um', 'um', 'julia'],
#  ['carol', 'julia', 'susan', 'agreed', 'minnie'],
#  ['ross',
#   'sfunny',
#   'um',
#   'uh',
#   'agreed',
#   'wed',
#   'spend',
#   'rest',
#   'lives',
#   'together'],
#  ['things', 'change', 'roll', 'punches'],
#  ['believe', 'julias', 'table'],
#  ['scene',
#   'barrys',
#   'office',
#   'rachel',
#   'makeup',
#   'mirror',
#   'barrys',
#   'lamp',
#   'barry',
#   'enters'],
#  ['barry', 'sorry'],
#  ['rachel', 'oh', 'much'],
#  ['ii', 'got', 'job'],
#  ['barry', 'oh', 'thats', 'great'],
#  ['rachel', 'tanned'],
#  ['barry', 'oh', 'uh', 'went', 'aruba'],
#  ['rachel', 'oh'],
#  ['went', 'honeymoon', 'alone'],
#  ['barry'],
#  ['went', 'uh', 'may', 'hurt'],
#  ['robbie'],
#  ['barry'],
#  ['rachel', 'went', 'mindy'],
#  ['rachel', 'mindy'],
#  ['maid', 'honour', 'mindy'],
#  ['barry', 'yeah', 'well', 'uh', 'kind', 'thing'],
#  ['rachel', 'oh'],
#  ['well', 'um', 'grabs', 'forehand', 'youve', 'got', 'plugs'],
#  ['barry', 'careful'],
#  ['havent', 'quite', 'taken', 'yet'],
#  ['rachel', 'youve', 'got', 'lenses'],
#  ['hate', 'sticking', 'finger', 'eye'],
#  ['barry'],
#  ['listen', 'really', 'wanted', 'thank'],
#  ['rachel', 'okay', 'barry', 'see', 'month', 'ago', 'wanted', 'hurt'],
#  ['ive', 'ever', 'wanted', 'hurt', 'anyone', 'life'],
#  ['im', 'orthodontist'],
#  ['rachel', 'wow'],
#  ['barry', 'know', 'right'],
#  ['mean', 'thought', 'happy'],
#  ['werent', 'happy'],
#  ['mindy', 'im', 'happy'],
#  ['spit'],
#  ['rachel'],
#  ['robbie'],
#  ['spits'],
#  ['rachel', 'anyway', 'um', 'gets', 'ring', 'purse'],
#  ['guess', 'belongs'],
#  ['thank', 'giving'],
#  ['barry', 'well', 'thank', 'giving', 'back'],
#  ['barry', 'rachel', 'look'],
#  ['robbie', 'hello'],
#  ['scene', 'carols', 'obgyn', 'theyre', 'still', 'arguing', 'name', 'baby'],
#  ['susan', 'oh', 'please'],
#  ['whats', 'wrong', 'helen'],
#  ['ross', 'helen', 'geller'],
#  ['dont', 'think'],
#  ['carol', 'hello'],
#  ['gonna', 'helen', 'geller'],
#  ['ross', 'thank'],
#  ['carol', 'mean', 'geller'],
#  ['ross', 'gonna', 'helen', 'willick'],
#  ['carol', 'actually', 'um', 'talked', 'helen', 'willickbunch'],
#  ['ross', 'well', 'wait', 'minute', 'wha', 'title'],
#  ['susan', 'baby'],
#  ['ross', 'oh', 'sfunny', 'really'],
#  ['um', 'dont', 'remember', 'making', 'sperm'],
#  ['susan', 'yeah', 'know', 'challenge'],
#  ['carol', 'right', 'two', 'stop'],
#  ['ross', 'gets', 'credit', 'hey', 'im'],
#  ['carol', 'ross'],
#  ['youre', 'actually', 'suggesting', 'helen'],
#  ['cause', 'think', 'borders', 'child', 'abuse'],
#  ['ross', 'course', 'im', 'suggesting'],
#  ['susan', 'oh', 'nonononono', 'see', 'hes'],
#  ['knows',
#   'noones',
#   'gonna',
#   'say',
#   'names',
#   'theyll',
#   'wind',
#   'calling',
#   'geller',
#   'gets',
#   'way'],
#  ['ross', 'way'],
#  ['youyou', 'think', 'way'],
#  ['believe', 'ways', 'ever', 'imagined', 'moment', 'life', 'way', 'yknow'],
#  ['uh', 'um', 'hard'],
#  ['im', 'cant', 'dr', 'oberman', 'entering', 'knock', 'knockhow', 'today'],
#  ['nausea'],
#  ['yeah'],
#  ['yeah'],
#  ['little'],
#  ['dr', 'oberman', 'well', 'wondering', 'mothertobe', 'thanks', 'sharing'],
#  ['carol', 'uh', 'lie', 'back', 'ross', 'uh', 'yknow', 'im', 'gonna', 'go'],
#  ['dont', 'dont', 'think', 'involved', 'particular', 'thing', 'right'],
#  ['turns', 'go', 'sound', 'sonogram', 'catches', 'hes', 'ear'],
#  ['returns', 'stares'],
#  ['ross', 'oh', 'god'],
#  ['susan', 'look'],
#  ['carol', 'know'],
#  ['closing',
#   'credits',
#   'scene',
#   'monica',
#   'rachels',
#   'apartment',
#   'everyone',
#   'watching',
#   'tape',
#   'sonogram'],
#  ['rachel', 'phone'],
#  ['ross', 'well'],
#  ['isnt', 'amazing'],
#  ['joey', 'supposed', 'seeing'],
#  ['chandler', 'dunno'],
#  ['think', 'attack', 'enterprise'],
#  ['phoebe',
#   'know',
#   'tilt',
#   'head',
#   'left',
#   'relax',
#   'eyes',
#   'kinda',
#   'looks',
#   'like',
#   'old',
#   'potato'],
#  ['ross', 'dont', 'alright'],
#  ['phoebe', 'okay'],
#  ['ross', 'walks', 'monica', 'standingmonica'],
#  ['whaddya', 'think'],
#  ['monica', 'welling', 'mmhmm'],
#  ['ross', 'wh', 'welling'],
#  ['monica'],
#  ['ross', 'youre', 'welling'],
#  ['monica'],
#  ['ross', 'youre', 'gonna', 'aunt'],
#  ['monica', 'pushes', 'starts', 'cry', 'oh', 'shut'],
#  ['rachel', 'phone', 'hi', 'mindy'],
#  ['hi', 'itits', 'rachel'],
#  ['yeah', 'im', 'fine'],
#  ['ii', 'saw', 'barry', 'today'],
#  ['oh', 'yeah', 'yeah', 'hehe', 'told'],
#  ['okay'],
#  ['hope', 'two', 'happy', 'really'],
#  ['oh',
#   'oh',
#   'mind',
#   'yknow',
#   'ifif',
#   'everything',
#   'works',
#   'guys',
#   'end',
#   'getting',
#   'married',
#   'kids',
#   'everything',
#   'hope',
#   'old',
#   'hairline',
#   'old',
#   'nose'],
#  ['slams', 'phone'],
#  ['everyone', 'okay', 'know', 'cheap', 'shot', 'feel', 'much', 'better'],
#  ['end', 'one', 'thumb', 'written', 'jeffrey', 'astrof', 'mike', 'sikowitz'],
#  ['transcribed',
#   'guineapig',
#   'scene',
#   'central',
#   'perk',
#   'everyone',
#   'phoebe'],
#  ['phoebe', 'entering', 'hi', 'guys'],
#  ['hey', 'pheebs'],
#  ['hi'],
#  ['ross', 'hey'],
#  ['oh', 'oh', 'howd', 'go'],
#  ['phoebe', 'um', 'good'],
#  ['walked', 'subway', 'said'],
#  ['ohh'],
#  ['ouch'],
#  ['rachel'],
#  ['said', 'thats', 'good', 'right'],
#  ['monica', 'uh'],
#  ['loosely', 'translated', 'means', 'never', 'see', 'naked'],
#  ['rachel', 'since'],
#  ['joey', 'since', 'always'],
#  ['like', 'dating', 'language'],
#  ['yknow', 'like', 'means'],
#  ['chandler',
#   'youre',
#   'nice',
#   'guy',
#   'means',
#   'im',
#   'gonna',
#   'dating',
#   'leatherwearing',
#   'alcoholics',
#   'complaining'],
#  ['phoebe',
#   'yknow',
#   'um',
#   'think',
#   'see',
#   'people',
#   'means',
#   'ha',
#   'ha',
#   'already'],
#  ['rachel', 'everybody', 'knows'],
#  ['joey', 'yeah'],
#  ['cushions', 'blow'],
#  ['chandler',
#   'yeah',
#   'like',
#   'youre',
#   'kid',
#   'parents',
#   'put',
#   'dog',
#   'sleep',
#   'tell',
#   'went',
#   'live',
#   'farm'],
#  ['ross',
#   'thats',
#   'funny',
#   'uh',
#   'parents',
#   'actually',
#   'uh',
#   'send',
#   'dog',
#   'live',
#   'farm'],
#  ['monica', 'uh', 'ross'],
#  ['ross'],
#  ['wh', 'hello'],
#  ['millners', 'farm', 'connecticut'],
#  ['millners',
#   'unbelievable',
#   'farm',
#   'horses',
#   'rabbits',
#   'could',
#   'chase',
#   'oh',
#   'god',
#   'chi',
#   'chi'],
#  ['opening',
#   'credits',
#   'scene',
#   'chandler',
#   'joeys',
#   'chandler',
#   'helping',
#   'joey',
#   'rehearse',
#   'part'],
#  ['chandler', 'feel', 'knowing', 'youre', 'die'],
#  ['joey', 'warden', 'five', 'minutes', 'pain'],
#  ['youll', 'live', 'knowledge', 'sent', 'honest', 'man', 'die'],
#  ['chandler', 'hey', 'really', 'good'],
#  ['joey', 'thanks'],
#  ['lets', 'keep', 'going'],
#  ['chandler', 'okay'],
#  ['whaddya', 'want', 'damone', 'huh'],
#  ['joey', 'wanna', 'go', 'back', 'cell'],
#  ['cause', 'cell', 'smoke'],
#  ['chandler', 'smoke', 'away'],
#  ['joey', 'takes', 'pack', 'cigarettes', 'lighter'],
#  ['fumbles', 'drops', 'lighter'],
#  ['lights', 'cigarett', 'takes', 'drag', 'coughs'],
#  ['chandler', 'think', 'probably', 'damone', 'smokes', 'cell', 'alone'],
#  ['joey'],
#  ['chandler', 'relax', 'hand'],
#  ['joey', 'lets', 'wrist', 'go', 'limp'],
#  ['chandler', 'much'],
#  ['joey', 'whoah'],
#  ['chandler', 'hey'],
#  ['joey', 'hey'],
#  ['chandler', 'alright', 'try', 'taking', 'puff'],
#  ['joey', 'tries', 'visibly', 'winces'],
#  ['chandler', 'alright', 'okay'],
#  ['give'],
#  ['joey', 'giving', 'cigarette'],
#  ['chandler', 'fine', 'fine'],
#  ['look', 'wanna', 'get', 'part'],
#  ['joey', 'reluctantly', 'gives', 'cigarette'],
#  ['chandler', 'dont', 'think', 'cigarette'],
#  ['think', 'thing', 'thats', 'missing', 'hand'],
#  ['youre', 'holding', 'feel', 'right'],
#  ['feel', 'complete'],
#  ['joey', 'ymiss'],
#  ['chandler', 'nah', 'much'],
#  ['alright', 'smoke'],
#  ['takes', 'puff'],
#  ['oh', 'god'],
#  ['continues', 'smoke'],
#  ['scene', 'central', 'perk', 'everyone', 'except', 'phoebe', 'rachel'],
#  ['monica'],
#  ['say', 'distance', 'tip', 'guys', 'thumb', 'tip', 'index', 'finger'],
#  ['guys', 'stretch', 'fingers'],
#  ['joey', 'thats', 'ridiculous'],
#  ['ross', 'use', 'either', 'thumb'],
#  ['rachel',
#   'carrying',
#   'tray',
#   'drinks',
#   'alright',
#   'dont',
#   'tell',
#   'dont',
#   'tell'],
#  ['starts', 'handing'],
#  ['decaf', 'cappucino', 'joey', 'coffee', 'black', 'late', 'iced', 'tea'],
#  ['im', 'getting', 'pretty', 'good'],
#  ...]

# %%
model = gensim.models.Word2Vec(
    window=5,
    min_count=3, # accept those sentence which have minimum 2 words
    workers=4,
)

# %%
model.build_vocab(story)
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (1935714, 2523405)

# %%
model.wv.most_similar('monica')
# Out:
# [('rachel', 0.9022611975669861),
#  ('joey', 0.8894322514533997),
#  ('phoebe', 0.8859913945198059),
#  ('chandler', 0.8694720268249512),
#  ('ross', 0.8503302931785583),
#  ('richard', 0.8176605105400085),
#  ('janice', 0.8173155188560486),
#  ('director', 0.7943333983421326),
#  ('charlie', 0.793239176273346),
#  ('prepares', 0.7930054664611816)]

# %%
model.wv.doesnt_match(['monica', 'ross', 'rachel', 'god'])
# Out:
# 'god'

# %%
model.wv['god']
# Out:
# array([ 0.12647986,  0.6324237 ,  0.23100482,  0.27130836, -0.54711837,
#        -0.5107276 , -0.19341524,  0.53490585, -0.26771402, -0.992168  ,
#         0.4614105 , -0.48921087, -0.11243579, -0.15063037,  0.03743075,
#        -0.41749555, -0.75178134, -0.29678714,  0.87452304,  0.27141798,
#         0.26156974,  0.629999  ,  0.70012945, -0.49424198, -0.13978851,
#        -0.15837479, -0.02515627,  0.1013075 , -1.2913133 , -0.10765205,
#         0.38299158, -0.41049555, -0.05912616, -0.64592266,  0.49805903,
#         0.5199852 , -0.34234056, -0.51566625, -0.5690701 , -1.2143178 ,
#        -0.7700002 ,  0.27824387, -0.67997146, -0.5456082 ,  1.251073  ,
#         0.14815335, -0.2833409 ,  0.04296072,  1.0374486 , -0.06136849,
#         0.19226089,  0.5729111 , -0.4096994 , -0.6800472 ,  0.93205684,
#         0.20969357, -0.0200164 ,  0.33773163, -0.8448624 , -0.347364  ,
#        -0.3375328 ,  0.6526577 , -0.18833412, -0.37180337, -1.1175246 ,
#         0.29297027, -0.25829402, -0.1489798 , -0.59162116,  0.47930494,
#        -0.43805504,  0.4510735 ,  0.93231106, -0.5462996 , -0.04376221,
#         0.5389394 ,  0.4088185 , -1.0855936 , -0.31528288, -0.0057262 ,
#        -0.4075652 , -0.03220417, -1.4934988 ,  1.2449375 , -0.51093423,
#        -0.534436  , -0.31197876,  0.4667835 ,  0.8891735 ,  0.7545668 ,
#         0.29357904,  0.57803804,  0.7726544 ,  0.14045873,  1.1023376 ,
#         0.7696857 ,  0.3700336 , -0.12788202,  0.37940478, -1.1090837 ],
#       dtype=float32)

# %%
model.wv.similarity('monica', 'rachel')
# Out:
# 0.90226114

# %%
model.wv.similarity('monica','prepares')
# Out:
# 0.79300547

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.11973665,  0.09132571,  0.04844841, ..., -0.06417389,
#          0.03241246, -0.00636536],
#        [-0.09749118,  0.09035764,  0.01769856, ..., -0.1217326 ,
#          0.01883168, -0.03519715],
#        [-0.04357055,  0.00378253, -0.0143761 , ..., -0.0910714 ,
#          0.05450577, -0.06092392],
#        ...,
#        [-0.07375094,  0.02880119,  0.0659207 , ..., -0.06379627,
#          0.0873814 , -0.01232543],
#        [-0.133145  ,  0.15163696,  0.00059921, ..., -0.12095088,
#          0.01514413,  0.0160448 ],
#        [-0.08627254,  0.0618843 ,  0.0827368 , ..., -0.15616688,
#         -0.02667997,  0.08258495]], dtype=float32)

# %%
model.wv.get_normed_vectors().shape
# Out:
# (8252, 100)

# %%
y = model.wv.index_to_key

# %%
y
# Out:
# ['ross',
#  'rachel',
#  'monica',
#  'chandler',
#  'joey',
#  'phoebe',
#  'oh',
#  'im',
#  'yeah',
#  'know',
#  'okay',
#  'well',
#  'dont',
#  'hey',
#  'right',
#  'like',
#  'scene',
#  'get',
#  'gonna',
#  'youre',
#  'go',
#  'thats',
#  'one',
#  'really',
#  'look',
#  'think',
#  'uh',
#  'yknow',
#  'see',
#  'mean',
#  'back',
#  'got',
#  'want',
#  'come',
#  'good',
#  'god',
#  'cant',
#  'guys',
#  'going',
#  'would',
#  'sorry',
#  'hi',
#  'time',
#  'little',
#  'ok',
#  'great',
#  'hes',
#  'say',
#  'tell',
#  'guy',
#  'yes',
#  'didnt',
#  'door',
#  'ill',
#  'something',
#  'room',
#  'could',
#  'shes',
#  'love',
#  'thing',
#  'starts',
#  'looks',
#  'rachels',
#  'take',
#  'still',
#  'apartment',
#  'wait',
#  'make',
#  'way',
#  'maybe',
#  'said',
#  'phone',
#  'us',
#  'umm',
#  'mr',
#  'enters',
#  'man',
#  'two',
#  'theres',
#  'whats',
#  'around',
#  'much',
#  'never',
#  'entering',
#  'ive',
#  'sure',
#  'big',
#  'wanna',
#  'thank',
#  'goes',
#  'wow',
#  'away',
#  'first',
#  'believe',
#  'people',
#  'need',
#  'looking',
#  'thought',
#  'talk',
#  'please',
#  'lets',
#  'give',
#  'walks',
#  'let',
#  'woman',
#  'joeys',
#  'even',
#  'baby',
#  'mike',
#  'fine',
#  'work',
#  'gets',
#  'actually',
#  'huh',
#  'doesnt',
#  'new',
#  'theyre',
#  'central',
#  'geller',
#  'getting',
#  'perk',
#  'talking',
#  'ah',
#  'cut',
#  'head',
#  'night',
#  'anything',
#  'hands',
#  'nice',
#  'listen',
#  'ii',
#  'mrs',
#  'call',
#  'last',
#  'stuff',
#  'thanks',
#  'um',
#  'pause',
#  'rach',
#  'chandlers',
#  'table',
#  'feel',
#  'turns',
#  'ever',
#  'day',
#  'ya',
#  'put',
#  'stop',
#  'hand',
#  'next',
#  'leave',
#  'gotta',
#  'dr',
#  'alright',
#  'start',
#  'another',
#  'together',
#  'place',
#  'emily',
#  'nothing',
#  'sitting',
#  'everyone',
#  'girl',
#  'guess',
#  'trying',
#  'honey',
#  'better',
#  'cause',
#  'told',
#  'ohh',
#  'break',
#  'ooh',
#  'takes',
#  'hello',
#  'someone',
#  'things',
#  'couch',
#  'kiss',
#  'face',
#  'married',
#  'lot',
#  'long',
#  'richard',
#  'bad',
#  'help',
#  'made',
#  'end',
#  'find',
#  'coming',
#  'monicas',
#  'friend',
#  'happy',
#  'wedding',
#  'credits',
#  'fun',
#  'name',
#  'janice',
#  'hear',
#  'remember',
#  'date',
#  'isnt',
#  'pretty',
#  'play',
#  'left',
#  'kinda',
#  'comes',
#  'wanted',
#  'points',
#  'pheebs',
#  'ready',
#  'friends',
#  'id',
#  'bathroom',
#  'carol',
#  'thinking',
#  'laughs',
#  'party',
#  'best',
#  'always',
#  'happened',
#  'coffee',
#  'rosss',
#  'opens',
#  'went',
#  'three',
#  'ben',
#  'tonight',
#  'bedroom',
#  'minute',
#  'leaves',
#  'ask',
#  'runs',
#  'else',
#  'keep',
#  'sees',
#  'everything',
#  'wrong',
#  'job',
#  'try',
#  'kind',
#  'home',
#  'funny',
#  'years',
#  'makes',
#  'youve',
#  'money',
#  'whole',
#  'old',
#  'hard',
#  'charlie',
#  'grabs',
#  'whos',
#  'sex',
#  'show',
#  'mom',
#  'office',
#  'phoebes',
#  'move',
#  'opening',
#  'dad',
#  'wont',
#  'totally',
#  'bye',
#  'today',
#  'life',
#  'care',
#  'behind',
#  'frank',
#  'puts',
#  'watch',
#  'living',
#  'hug',
#  'weird',
#  'emma',
#  'dinner',
#  'walk',
#  'game',
#  'second',
#  'saying',
#  'tv',
#  'sits',
#  'gunther',
#  'wasnt',
#  'wouldnt',
#  'hell',
#  'part',
#  'later',
#  'check',
#  'idea',
#  'course',
#  'already',
#  'kitchen',
#  'done',
#  'green',
#  'stupid',
#  'bed',
#  'yet',
#  'probably',
#  'crazy',
#  'making',
#  'wants',
#  'wearing',
#  'meet',
#  'open',
#  'cool',
#  'watching',
#  'pick',
#  'reading',
#  'might',
#  'everybody',
#  'playing',
#  'stay',
#  'picks',
#  'happen',
#  'commercial',
#  'david',
#  'front',
#  'window',
#  'picture',
#  'says',
#  'used',
#  'stops',
#  'couple',
#  'eric',
#  'enough',
#  'telling',
#  'supposed',
#  'anyway',
#  'excuse',
#  'taking',
#  'listens',
#  'tomorrow',
#  'problem',
#  'ring',
#  'called',
#  'eyes',
#  'gives',
#  'also',
#  'house',
#  'came',
#  'outside',
#  'sit',
#  'every',
#  'deal',
#  'havent',
#  'youll',
#  'tag',
#  'box',
#  'whoa',
#  'paul',
#  'kisses',
#  'since',
#  'doctor',
#  'susan',
#  'voice',
#  'parents',
#  'saw',
#  'holding',
#  'holds',
#  'live',
#  'hair',
#  'transcribed',
#  'girls',
#  'tries',
#  'may',
#  'eat',
#  'beautiful',
#  'morning',
#  'use',
#  'turn',
#  'enter',
#  'chair',
#  'kids',
#  'food',
#  'written',
#  'couldnt',
#  'real',
#  'year',
#  'miss',
#  'hold',
#  'standing',
#  'anymore',
#  'hot',
#  'pants',
#  'matter',
#  'seen',
#  'rest',
#  'book',
#  'throws',
#  'director',
#  'run',
#  'waiting',
#  'person',
#  'took',
#  'cute',
#  'found',
#  'understand',
#  'amy',
#  'forget',
#  'singing',
#  'shocked',
#  'gang',
#  'seeing',
#  'heard',
#  'women',
#  'moving',
#  'thinks',
#  'knew',
#  'hate',
#  'boy',
#  'story',
#  'laughing',
#  'sleep',
#  'high',
#  'birthday',
#  'somebody',
#  'exits',
#  'bag',
#  'gave',
#  'heres',
#  'youd',
#  'walking',
#  'bit',
#  'movie',
#  'without',
#  'weve',
#  'car',
#  'uhhuh',
#  'different',
#  'bing',
#  'sister',
#  'mona',
#  'number',
#  'sweet',
#  'side',
#  'dog',
#  'must',
#  'mine',
#  'laugh',
#  'late',
#  'finally',
#  'alone',
#  'cat',
#  'nono',
#  'mind',
#  'working',
#  'gone',
#  'father',
#  'cry',
#  'five',
#  'question',
#  'bring',
#  'days',
#  'uhh',
#  'sounds',
#  'though',
#  'kathy',
#  'means',
#  'four',
#  'amazing',
#  'sound',
#  'uhm',
#  'street',
#  'arent',
#  'joshua',
#  'hall',
#  'quickly',
#  'kidding',
#  'pete',
#  'restaurant',
#  'naked',
#  'huge',
#  'serious',
#  'true',
#  'close',
#  'ball',
#  'inside',
#  'running',
#  'elizabeth',
#  'julie',
#  'dress',
#  'set',
#  'closes',
#  'almost',
#  'tape',
#  'fact',
#  'read',
#  'ahh',
#  'minutes',
#  'closing',
#  'ago',
#  'eating',
#  'card',
#  'point',
#  'rings',
#  'babies',
#  'knock',
#  'counter',
#  'anyone',
#  'mark',
#  'leaving',
#  'hugs',
#  'either',
#  'half',
#  'erica',
#  'floor',
#  'nods',
#  'drink',
#  'aasen',
#  'line',
#  'excited',
#  'world',
#  'worry',
#  'throw',
#  'hope',
#  'ow',
#  'times',
#  'dude',
#  'mouth',
#  'dance',
#  'hang',
#  'change',
#  'hallway',
#  'heads',
#  'carrying',
#  'andand',
#  'crying',
#  'moves',
#  'waiter',
#  'started',
#  'school',
#  'important',
#  'towards',
#  'hangs',
#  'moment',
#  'cmon',
#  'knows',
#  'kid',
#  'machine',
#  'lost',
#  'jill',
#  'giving',
#  'chance',
#  'mad',
#  'marcel',
#  'hours',
#  'gary',
#  'pulls',
#  'mon',
#  'janine',
#  'coat',
#  'answer',
#  'met',
#  'wish',
#  'ursula',
#  'except',
#  'suddenly',
#  'waltham',
#  'london',
#  'ass',
#  'paper',
#  'fire',
#  'perfect',
#  'reason',
#  'pregnant',
#  'word',
#  'wear',
#  'christmas',
#  'duck',
#  'six',
#  'joe',
#  'youyou',
#  'kissing',
#  'absolutely',
#  'seriously',
#  'tribbiani',
#  'clothes',
#  'yelling',
#  'least',
#  'wife',
#  'broke',
#  'hat',
#  'easy',
#  'hit',
#  'anybody',
#  'luck',
#  'many',
#  'mother',
#  'exactly',
#  'buy',
#  'joke',
#  'notices',
#  'glad',
#  'em',
#  'whatever',
#  'song',
#  'gasps',
#  'asked',
#  'class',
#  'relationship',
#  'nonono',
#  'sweetie',
#  'camera',
#  'nurse',
#  'ugh',
#  'win',
#  'family',
#  'arm',
#  'answers',
#  'top',
#  'goodbye',
#  'bet',
#  'stands',
#  'lady',
#  'along',
#  'shouldnt',
#  'butt',
#  'marry',
#  'hows',
#  'water',
#  'thanksgiving',
#  'lives',
#  'boyfriend',
#  'hurt',
#  'pay',
#  'barry',
#  'audition',
#  'glares',
#  'shows',
#  'earlier',
#  'jack',
#  'fake',
#  'itll',
#  'piece',
#  'dead',
#  'dollars',
#  'week',
#  'boss',
#  'cannot',
#  'knocks',
#  'cup',
#  'pizza',
#  'fat',
#  'tickets',
#  'lunch',
#  'staring',
#  'kill',
#  'asleep',
#  'upset',
#  'hospital',
#  'mnca',
#  'across',
#  'feeling',
#  'welcome',
#  'news',
#  'kate',
#  'realizes',
#  'iii',
#  'soon',
#  'city',
#  'free',
#  'seems',
#  'meant',
#  'figure',
#  'message',
#  'shut',
#  'putting',
#  'shot',
#  'sick',
#  'seat',
#  'promise',
#  'shower',
#  'wine',
#  'past',
#  'ones',
#  'building',
#  'eddie',
#  'werent',
#  'gavin',
#  'ten',
#  'brought',
#  'young',
#  'falls',
#  'lapse',
#  'stand',
#  'store',
#  'stares',
#  'ice',
#  'talked',
#  'girlfriend',
#  'fight',
#  'terrible',
#  'die',
#  'present',
#  'smiles',
#  'ticket',
#  'returning',
#  'joanna',
#  'lose',
#  'hour',
#  'definitely',
#  'cab',
#  'bob',
#  'obviously',
#  'relax',
#  'sometimes',
#  'plate',
#  'marriage',
#  'surprise',
#  'york',
#  'lauren',
#  'able',
#  'pain',
#  'eye',
#  'interrupting',
#  'son',
#  'starting',
#  'small',
#  'doin',
#  'chicken',
#  'slowly',
#  'hits',
#  'drunk',
#  'shirt',
#  'teacher',
#  'wouldve',
#  'steve',
#  'chan',
#  'sexy',
#  'answering',
#  'actor',
#  'sign',
#  'seem',
#  'unless',
#  'plane',
#  'special',
#  'smiling',
#  'monkey',
#  'smell',
#  'sandwich',
#  'wheres',
#  'full',
#  'note',
#  'roommate',
#  'yep',
#  'shoulder',
#  'forgot',
#  'onto',
#  'weeks',
#  'men',
#  'gift',
#  'nobody',
#  'calling',
#  'hmm',
#  'continued',
#  'cheese',
#  'danny',
#  'air',
#  'afraid',
#  'jumps',
#  'fault',
#  'pass',
#  'aunt',
#  'candy',
#  'treeger',
#  'purse',
#  'lights',
#  'cake',
#  'assistant',
#  'fast',
#  'touch',
#  'dancing',
#  'confused',
#  'likes',
#  'middle',
#  'finger',
#  'lying',
#  'liked',
#  'massage',
#  'heart',
#  'finds',
#  'college',
#  'worried',
#  'wall',
#  'sir',
#  'desk',
#  'figured',
#  'agent',
#  'finish',
#  'music',
#  'bar',
#  'seven',
#  'sad',
#  'plan',
#  'phoe',
#  'returns',
#  'motions',
#  'mindy',
#  'milk',
#  'pushes',
#  'imim',
#  'sr',
#  'worse',
#  'scared',
#  'pointing',
#  'chick',
#  'angrily',
#  'hotel',
#  'turning',
#  'sleeping',
#  'light',
#  'ohhh',
#  'feet',
#  'asking',
#  'ending',
#  'gay',
#  'bill',
#  'writing',
#  'fridge',
#  'smile',
#  'eh',
#  'order',
#  'dating',
#  'shakes',
#  'list',
#  'keys',
#  'ralph',
#  'bought',
#  'entire',
#  'glass',
#  'stuck',
#  'quit',
#  'sweater',
#  'fingers',
#  'months',
#  'words',
#  'tried',
#  'hundred',
#  'straight',
#  'husband',
#  'bucks',
#  'bunch',
#  'feelings',
#  'looked',
#  'porn',
#  'screaming',
#  'paolo',
#  'wed',
#  'apparently',
#  'moved',
#  'missed',
#  'hanging',
#  'interesting',
#  'eight',
#  'grab',
#  'horrible',
#  'damn',
#  'lie',
#  'third',
#  'nose',
#  'alice',
#  'closer',
#  'bottle',
#  'feels',
#  'shoes',
#  'smoke',
#  'far',
#  'buddy',
#  'wondering',
#  'grandmother',
#  'worked',
#  'picked',
#  'brother',
#  'ha',
#  'flight',
#  'drake',
#  'spend',
#  'stunned',
#  'seconds',
#  'surprised',
#  'smart',
#  'video',
#  'cards',
#  'doug',
#  'bitch',
#  'cold',
#  'drops',
#  'completely',
#  'turkey',
#  'cookies',
#  'ear',
#  'showing',
#  'less',
#  'kim',
#  'catch',
#  'needs',
#  'magazine',
#  'beer',
#  'lucky',
#  'dream',
#  'guest',
#  'meeting',
#  'daddy',
#  'dressed',
#  'body',
#  'bobby',
#  'leg',
#  'fall',
#  'boxes',
#  'pull',
#  'yay',
#  'balcony',
#  'using',
#  'fair',
#  'checking',
#  'accent',
#  'died',
#  'felt',
#  'museum',
#  'although',
#  'cooking',
#  'loved',
#  'whatwhat',
#  'weekend',
#  'calls',
#  'kissed',
#  'cookie',
#  'dear',
#  'key',
#  'happens',
#  'realize',
#  'bra',
#  'arms',
#  'fired',
#  'others',
#  'extra',
#  'red',
#  'stairs',
#  'finished',
#  'tim',
#  'conversation',
#  'business',
#  'la',
#  'plus',
#  'heyhey',
#  'child',
#  'write',
#  'control',
#  'drinking',
#  'nervous',
#  'chip',
#  'slept',
#  'airport',
#  'interviewer',
#  'stick',
#  'legs',
#  'black',
#  'step',
#  'none',
#  'estelle',
#  'listening',
#  'professor',
#  'underwear',
#  'white',
#  'covers',
#  'clean',
#  'wonderful',
#  'wewe',
#  'freak',
#  'breakfast',
#  'bonnie',
#  'whatre',
#  'works',
#  'interview',
#  'ladies',
#  'noise',
#  'robert',
#  'thatthat',
#  'flowers',
#  'push',
#  'park',
#  'dina',
#  'casting',
#  'quite',
#  'clear',
#  'boat',
#  'case',
#  'sense',
#  'nope',
#  'checks',
#  'jacket',
#  'yesterday',
#  'save',
#  'forever',
#  'zelner',
#  'congratulations',
#  'greene',
#  'sing',
#  'secret',
#  'glasses',
#  ...]

# %% [markdown]
# # **Reducing dimension to see visual graph**

# %%
pca = PCA(n_components=3)
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X.shape
# Out:
# (8252, 3)

# %%
fig = px.scatter_3d(X[:100], x = 0, y=1, z=2, color=y[:100])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="54c23bac-1dee-423a-8551-acbe723ba71d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54c23bac-1dee-423a-8551-acbe723ba71d")) {                    Plotly.newPlot(                        "54c23bac-1dee-423a-8551-acbe723ba71d",                        [{"hovertemplate":"color=ross\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ross","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"ross","scene":"scene","showlegend":true,"x":[0.061361257],"y":[-0.24138004],"z":[0.192062],"type":"scatter3d"},{"hovertemplate":"color=rachel\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rachel","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"rachel","scene":"scene","showlegend":true,"x":[0.059774738],"y":[-0.30617186],"z":[0.16011567],"type":"scatter3d"},{"hovertemplate":"color=monica\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"monica","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"monica","scene":"scene","showlegend":true,"x":[-0.021890346],"y":[-0.27813905],"z":[0.15904815],"type":"scatter3d"},{"hovertemplate":"color=chandler\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"chandler","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"chandler","scene":"scene","showlegend":true,"x":[-0.011115726],"y":[-0.20593491],"z":[0.17806146],"type":"scatter3d"},{"hovertemplate":"color=joey\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"joey","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"joey","scene":"scene","showlegend":true,"x":[-0.0031872205],"y":[-0.22928792],"z":[0.16487232],"type":"scatter3d"},{"hovertemplate":"color=phoebe\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"phoebe","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"phoebe","scene":"scene","showlegend":true,"x":[0.06363883],"y":[-0.28365725],"z":[0.105310425],"type":"scatter3d"},{"hovertemplate":"color=oh\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"oh","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"oh","scene":"scene","showlegend":true,"x":[0.31160325],"y":[-0.426118],"z":[0.009266049],"type":"scatter3d"},{"hovertemplate":"color=im\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"im","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"im","scene":"scene","showlegend":true,"x":[0.36304036],"y":[-0.078872494],"z":[0.08218987],"type":"scatter3d"},{"hovertemplate":"color=yeah\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"yeah","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"yeah","scene":"scene","showlegend":true,"x":[0.61628103],"y":[-0.20948768],"z":[0.013957277],"type":"scatter3d"},{"hovertemplate":"color=know\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"know","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"know","scene":"scene","showlegend":true,"x":[0.66990364],"y":[0.09196996],"z":[0.082503],"type":"scatter3d"},{"hovertemplate":"color=okay\u003cbr\u003e0=%{x}\u003cbr\u003e ...
